# %%
import pandas as pd
from neo4j import GraphDatabase
from time import sleep
from random import randint
import ast

# %%
# 1. Load CSV file and convert 'menu' and 'embedding' to list
# -----------------------------------------------------------------------------
df = pd.read_csv('wave_emb_dbmcv2.csv')
df = df.drop(['Unnamed: 0'], axis=1)
print(f"Tipe data nilai pada kolom 'menu' sebelum konversi: {type(df['menu'][0])}\nTipe data nilai pada kolom 'embedding' sebelum konversi: {type(df['embedding'][0])}")
df['menu'] = df['menu'].apply(ast.literal_eval)
df['embedding'] = df['embedding'].apply(ast.literal_eval)
print(f"Tipe data nilai pada kolom 'menu' setelah konversi: {type(df['menu'][0])}\nTipe data nilai pada kolom 'embedding' setelah konversi: {type(df['embedding'][0])}")
df
# Out:
# Tipe data nilai pada kolom 'menu' sebelum konversi: <class 'str'>
# Tipe data nilai pada kolom 'embedding' sebelum konversi: <class 'str'>
# Tipe data nilai pada kolom 'menu' setelah konversi: <class 'list'>
# Tipe data nilai pada kolom 'embedding' setelah konversi: <class 'list'>
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2827                                   virinda food
# 2828                                       wouwcake
# 2829                                        yuk tri
# 2830                                           zara
# 2831  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu              city  \
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...          Surabaya
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...  Kabupaten Gresik
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...            Malang
# 3                            [KRUPUK BAWANG RANIS KDS ]            Malang
# 4                         [Kacang Goreng Winarti Snack]          Surabaya
# ...                                                 ...               ...
# 2827                                   [Rolade, Sempol]            Malang
# 2828  [risoles wouwcake, kue tar wouwcake, kroket ke...          Surabaya
# 2829       [kue nastar, kue kastengel, kue putri salju]            Malang
# 2830                                   [stik keju zara]            Malang
# 2831                 [Tape Ketan Kartika Khas Kuningan]        Kota Depok
#
#                                alt_resto  \
# 0                       ['Dapur Fizzul']
# 1            ['Rawon Balungan H. Mufid']
# 2                        ['Sambat Luwe']
# 3           ['KDS Cantonese Restaurant']
# 4               ['Nathania Snack House']
# ...                                  ...
# 2827                  ['Javanine Resto']
# 2828           ['Warung wong lue (WWL)']
# 2829                  ['Trimurti Resto']
# 2830       ['Lafayette Coffee & Eatery']
# 2831  ['Tape Ketan Putih Khas Kuningan']
#
#                                               embedding
# 0     [[-0.02187000773847103, 0.01127985492348671, -...
# 1     [[0.01963287591934204, 0.056399986147880554, 0...
# 2     [[0.009273191913962364, 0.03742887079715729, -...
# 3     [[-0.08321938663721085, 0.05083480849862099, 0...
# 4     [[-0.09416132420301437, 0.10255325585603714, 0...
# ...                                                 ...
# 2827  [[-0.024130970239639282, 0.0011671549873426557...
# 2828  [[-0.03364633023738861, 0.07875539362430573, -...
# 2829  [[-0.010088230483233929, -0.05614767223596573,...
# 2830  [[0.004909013397991657, -0.049723122268915176,...
# 2831  [[-0.002083861967548728, 0.04289808124303818, ...
#
# [2832 rows x 5 columns]

# %%
# 2. Neo4j connection & similarity helpers
# -----------------------------------------------------------------------------
drv = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))

def find_similar_restaurants_by_embedding(alts_embs: list[list[float]], threshold=0.6, topk=2):
    ids = []
    with drv.session() as ses:
        for emb in alts_embs:
            # Kueri ini mengembalikan properti 'r_id' dari node
            rows = ses.run("""
                CALL db.index.vector.queryNodes('restaurant_emb_dbmcv2', $topk, $emb)
                YIELD node, score
                WHERE score >= $threshold
                OPTIONAL MATCH (other:Restaurant)-[s:SIMILAR_TO_DBMCV2]->(node)
                    WHERE s.score >= $threshold
                RETURN DISTINCT node.r_id AS id, collect(other.r_id) AS linked_ids
                """, emb=emb, threshold=threshold, topk=topk)
            for r in rows:
                if r["id"] is not None:
                    ids.append(r["id"])
                ids.extend(r["linked_ids"])
    return list(set(ids))

# Fungsi jaccard menerima list berisi string
def jaccard(list1: list[str], list2: list[str]) -> float:
    """Menghitung Jaccard similarity antara dua list string."""
    set1 = {item.lower().strip() for item in list1}
    set2 = {item.lower().strip() for item in list2}
    
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    
    return intersection / union if union != 0 else 0.0

# %%
# 3. Overclaim checker
# -----------------------------------------------------------------------------
def check_overclaim(menu_names: list[str], alts_embs: list[list[float]]):
    # 1) look up their node IDs in Neo4j
    rids_count = 1
    for i in range(10):
        rids = find_similar_restaurants_by_embedding(alts_embs)
        print(f"Number of attempts to find similar restaurants by emb: {rids_count}")
        if rids: break
        rids_count += 1
        sleep(randint(1, 2))

    # 2) compare each menu_item list against your query list
    issues = []
    max_jaccard_score = 0.0
    # Variabel untuk menyimpan data perbandingan terbaik
    best_comp_name = None
    best_comp_menu = []
    
    with drv.session() as ses:
        for rid in rids:
            result = ses.run(
                """
                MATCH (r:Restaurant {r_id:$rid})
                OPTIONAL MATCH (r)-[:HAS_PRODUCT]->(m:Menu)
                RETURN r.restaurant AS restaurant_name, collect(m.menu) AS actual_menus
                """, rid=rid
            )
            rec = result.single()
            if rec and rec["restaurant_name"]:
                db_resto_name = rec["restaurant_name"]
                # Gunakan variabel ini untuk mengisi comp_menu nantinya
                actual_menus = rec["actual_menus"]

                split_menus = [item.split()[0] for item in actual_menus if item and item.strip()]

                score = jaccard(split_menus, menu_names)

                # Cek jika ini adalah skor tertinggi yang ditemukan sejauh ini
                if score > max_jaccard_score:
                    max_jaccard_score = score
                    best_comp_name = db_resto_name
                    # Simpan menu asli (bukan yang di-split)
                    best_comp_menu = actual_menus

                if score < 0.3:
                    issues.append({
                        "restaurant_id": rid,
                        "restaurant_name": db_resto_name,
                        "jaccard_score": score
                    })

    # Mengembalikan issues, score tertinggi, nama, dan menu perbandingan terbaik
    return issues, max_jaccard_score, best_comp_name, best_comp_menu

# Fungsi evaluate_row mengembalikan tuple (status, score, comp_name, comp_menu)
def evaluate_row(menus: list[str], emb: list[list[float]]) -> tuple[str, float, str | None, list[str]]:
    """
    Mengevaluasi satu baris data, menentukan status berdasarkan Jaccard score akhir.
    """
    # Tangkap semua nilai yang dikembalikan oleh check_overclaim
    issues, score, comp_name, comp_menu = check_overclaim(menus, emb)
    
    status = "overclaim" if score < 0.3 else "aman"
    
    # Kembalikan semua data yang relevan
    return status, score, comp_name, comp_menu

# %%
# 4. Run on the "df" DataFrame
# -----------------------------------------------------------------------------
hasil = []
# Looping menangani score dan data perbandingan
for idx, row in df.iterrows():
    query_menus = [i.split()[0] for i in row["menu"] if i and i.strip()]
    
    # Tangkap semua nilai yang dikembalikan oleh evaluate_row
    status, score, comp_restaurant, comp_menu = evaluate_row(query_menus, row["embedding"])
    
    # Kondisi untuk append
    # Hanya tambahkan ke 'hasil' jika 'comp_restaurant' DAN 'comp_menu' tidak kosong.
    if comp_restaurant and comp_menu:
        hasil.append({
            "index": idx,
            "restaurant": row["restaurant"],
            "menu": row["menu"],
            "city": row["city"],
            "comp_restaurant": comp_restaurant,
            "comp_menu": comp_menu,
            "score": score,
            "status": status
        })
        print(f"Data valid ditemukan dan ditambahkan pada baris {idx+1} ✅ Total hasil sekarang: {len(hasil)}.")
    else:
        print(f"Data perbandingan kosong, baris {idx+1} dilewati ❌ Total hasil sekarang: {len(hasil)}.")

df_hasil = pd.DataFrame(hasil)
df_hasil
# Out:
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 1 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 3 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 4 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 5 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 6 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 7 ✅ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 8 ✅ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 9 dilewati ❌ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 10 dilewati ❌ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 11 ✅ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 12 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 13 ✅ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 14 dilewati ❌ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 15 dilewati ❌ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 16 ✅ Total hasil sekarang: 5.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 17 ✅ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 18 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 19 ✅ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 20 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 21 ✅ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 22 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 23 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 24 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 25 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 26 ✅ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 27 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 28 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 29 ✅ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 30 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 31 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 32 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 33 ✅ Total hasil sekarang: 11.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 34 dilewati ❌ Total hasil sekarang: 11.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 35 ✅ Total hasil sekarang: 12.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 36 dilewati ❌ Total hasil sekarang: 12.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 37 dilewati ❌ Total hasil sekarang: 12.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 38 ✅ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 39 ✅ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 40 ✅ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 41 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 42 ✅ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 43 dilewati ❌ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 44 dilewati ❌ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 45 ✅ Total hasil sekarang: 17.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 46 dilewati ❌ Total hasil sekarang: 17.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 47 ✅ Total hasil sekarang: 18.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 48 dilewati ❌ Total hasil sekarang: 18.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 49 dilewati ❌ Total hasil sekarang: 18.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 50 dilewati ❌ Total hasil sekarang: 18.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 51 dilewati ❌ Total hasil sekarang: 18.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 52 ✅ Total hasil sekarang: 19.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 53 dilewati ❌ Total hasil sekarang: 19.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 54 ✅ Total hasil sekarang: 20.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 55 ✅ Total hasil sekarang: 21.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 56 dilewati ❌ Total hasil sekarang: 21.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 57 dilewati ❌ Total hasil sekarang: 21.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 58 dilewati ❌ Total hasil sekarang: 21.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 59 ✅ Total hasil sekarang: 22.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 60 dilewati ❌ Total hasil sekarang: 22.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 61 dilewati ❌ Total hasil sekarang: 22.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 62 ✅ Total hasil sekarang: 23.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 63 ✅ Total hasil sekarang: 24.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 64 ✅ Total hasil sekarang: 25.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 65 dilewati ❌ Total hasil sekarang: 25.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 66 ✅ Total hasil sekarang: 26.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 67 dilewati ❌ Total hasil sekarang: 26.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 68 ✅ Total hasil sekarang: 27.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 69 ✅ Total hasil sekarang: 28.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 70 dilewati ❌ Total hasil sekarang: 28.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 71 ✅ Total hasil sekarang: 29.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 72 ✅ Total hasil sekarang: 30.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 73 ✅ Total hasil sekarang: 31.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 74 dilewati ❌ Total hasil sekarang: 31.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 75 dilewati ❌ Total hasil sekarang: 31.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 76 ✅ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 77 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 78 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 79 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 80 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 81 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 82 dilewati ❌ Total hasil sekarang: 32.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 83 ✅ Total hasil sekarang: 33.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 84 dilewati ❌ Total hasil sekarang: 33.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 85 ✅ Total hasil sekarang: 34.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 86 dilewati ❌ Total hasil sekarang: 34.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 87 dilewati ❌ Total hasil sekarang: 34.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 88 dilewati ❌ Total hasil sekarang: 34.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 89 dilewati ❌ Total hasil sekarang: 34.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 90 ✅ Total hasil sekarang: 35.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 91 ✅ Total hasil sekarang: 36.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 92 ✅ Total hasil sekarang: 37.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 93 dilewati ❌ Total hasil sekarang: 37.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 94 ✅ Total hasil sekarang: 38.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 95 ✅ Total hasil sekarang: 39.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 96 dilewati ❌ Total hasil sekarang: 39.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 97 ✅ Total hasil sekarang: 40.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 98 ✅ Total hasil sekarang: 41.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 99 ✅ Total hasil sekarang: 42.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 100 ✅ Total hasil sekarang: 43.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 101 ✅ Total hasil sekarang: 44.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 102 ✅ Total hasil sekarang: 45.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 103 ✅ Total hasil sekarang: 46.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 104 ✅ Total hasil sekarang: 47.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 105 dilewati ❌ Total hasil sekarang: 47.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 106 ✅ Total hasil sekarang: 48.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 107 dilewati ❌ Total hasil sekarang: 48.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 108 ✅ Total hasil sekarang: 49.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 109 dilewati ❌ Total hasil sekarang: 49.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 110 dilewati ❌ Total hasil sekarang: 49.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 111 ✅ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 112 dilewati ❌ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 113 dilewati ❌ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 114 dilewati ❌ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 115 dilewati ❌ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 116 dilewati ❌ Total hasil sekarang: 50.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 117 ✅ Total hasil sekarang: 51.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 118 dilewati ❌ Total hasil sekarang: 51.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 119 dilewati ❌ Total hasil sekarang: 51.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 120 ✅ Total hasil sekarang: 52.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 121 dilewati ❌ Total hasil sekarang: 52.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 122 dilewati ❌ Total hasil sekarang: 52.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 123 ✅ Total hasil sekarang: 53.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 124 dilewati ❌ Total hasil sekarang: 53.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 125 ✅ Total hasil sekarang: 54.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 126 ✅ Total hasil sekarang: 55.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 127 ✅ Total hasil sekarang: 56.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 128 ✅ Total hasil sekarang: 57.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 129 dilewati ❌ Total hasil sekarang: 57.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 130 dilewati ❌ Total hasil sekarang: 57.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 131 ✅ Total hasil sekarang: 58.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 132 dilewati ❌ Total hasil sekarang: 58.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 133 dilewati ❌ Total hasil sekarang: 58.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 134 ✅ Total hasil sekarang: 59.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 135 ✅ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 136 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 137 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 138 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 139 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 140 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 141 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 142 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 143 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 144 dilewati ❌ Total hasil sekarang: 60.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 145 ✅ Total hasil sekarang: 61.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 146 ✅ Total hasil sekarang: 62.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 147 dilewati ❌ Total hasil sekarang: 62.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 148 ✅ Total hasil sekarang: 63.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 149 ✅ Total hasil sekarang: 64.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 150 dilewati ❌ Total hasil sekarang: 64.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 151 ✅ Total hasil sekarang: 65.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 152 ✅ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 153 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 154 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Number of attempts to find similar restaurants by emb: 2
# Number of attempts to find similar restaurants by emb: 3
# Number of attempts to find similar restaurants by emb: 4
# Number of attempts to find similar restaurants by emb: 5
# Number of attempts to find similar restaurants by emb: 6
# Number of attempts to find similar restaurants by emb: 7
# Number of attempts to find similar restaurants by emb: 8
# Number of attempts to find similar restaurants by emb: 9
# Number of attempts to find similar restaurants by emb: 10
# Data perbandingan kosong, baris 155 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 156 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 157 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 158 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 159 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 160 dilewati ❌ Total hasil sekarang: 66.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 161 ✅ Total hasil sekarang: 67.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 162 ✅ Total hasil sekarang: 68.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 163 ✅ Total hasil sekarang: 69.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 164 ✅ Total hasil sekarang: 70.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 165 ✅ Total hasil sekarang: 71.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 166 ✅ Total hasil sekarang: 72.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 167 dilewati ❌ Total hasil sekarang: 72.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 168 dilewati ❌ Total hasil sekarang: 72.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 169 ✅ Total hasil sekarang: 73.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 170 ✅ Total hasil sekarang: 74.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 171 dilewati ❌ Total hasil sekarang: 74.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 172 dilewati ❌ Total hasil sekarang: 74.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 173 ✅ Total hasil sekarang: 75.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 174 ✅ Total hasil sekarang: 76.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 175 ✅ Total hasil sekarang: 77.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 176 dilewati ❌ Total hasil sekarang: 77.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 177 dilewati ❌ Total hasil sekarang: 77.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 178 dilewati ❌ Total hasil sekarang: 77.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 179 ✅ Total hasil sekarang: 78.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 180 dilewati ❌ Total hasil sekarang: 78.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 181 ✅ Total hasil sekarang: 79.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 182 ✅ Total hasil sekarang: 80.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 183 dilewati ❌ Total hasil sekarang: 80.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 184 dilewati ❌ Total hasil sekarang: 80.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 185 dilewati ❌ Total hasil sekarang: 80.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 186 ✅ Total hasil sekarang: 81.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 187 ✅ Total hasil sekarang: 82.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 188 dilewati ❌ Total hasil sekarang: 82.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 189 dilewati ❌ Total hasil sekarang: 82.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 190 ✅ Total hasil sekarang: 83.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 191 ✅ Total hasil sekarang: 84.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 192 dilewati ❌ Total hasil sekarang: 84.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 193 dilewati ❌ Total hasil sekarang: 84.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 194 ✅ Total hasil sekarang: 85.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 195 ✅ Total hasil sekarang: 86.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 196 ✅ Total hasil sekarang: 87.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 197 dilewati ❌ Total hasil sekarang: 87.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 198 ✅ Total hasil sekarang: 88.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 199 ✅ Total hasil sekarang: 89.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 200 ✅ Total hasil sekarang: 90.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 201 ✅ Total hasil sekarang: 91.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 202 ✅ Total hasil sekarang: 92.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 203 ✅ Total hasil sekarang: 93.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 204 ✅ Total hasil sekarang: 94.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 205 ✅ Total hasil sekarang: 95.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 206 dilewati ❌ Total hasil sekarang: 95.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 207 dilewati ❌ Total hasil sekarang: 95.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 208 dilewati ❌ Total hasil sekarang: 95.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 209 dilewati ❌ Total hasil sekarang: 95.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 210 ✅ Total hasil sekarang: 96.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 211 ✅ Total hasil sekarang: 97.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 212 dilewati ❌ Total hasil sekarang: 97.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 213 ✅ Total hasil sekarang: 98.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 214 dilewati ❌ Total hasil sekarang: 98.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 215 ✅ Total hasil sekarang: 99.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 216 ✅ Total hasil sekarang: 100.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 217 dilewati ❌ Total hasil sekarang: 100.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 218 ✅ Total hasil sekarang: 101.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 219 ✅ Total hasil sekarang: 102.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 220 ✅ Total hasil sekarang: 103.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 221 dilewati ❌ Total hasil sekarang: 103.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 222 dilewati ❌ Total hasil sekarang: 103.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 223 ✅ Total hasil sekarang: 104.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 224 dilewati ❌ Total hasil sekarang: 104.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 225 dilewati ❌ Total hasil sekarang: 104.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 226 dilewati ❌ Total hasil sekarang: 104.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 227 dilewati ❌ Total hasil sekarang: 104.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 228 ✅ Total hasil sekarang: 105.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 229 dilewati ❌ Total hasil sekarang: 105.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 230 dilewati ❌ Total hasil sekarang: 105.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 231 ✅ Total hasil sekarang: 106.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 232 ✅ Total hasil sekarang: 107.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 233 ✅ Total hasil sekarang: 108.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 234 ✅ Total hasil sekarang: 109.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 235 dilewati ❌ Total hasil sekarang: 109.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 236 dilewati ❌ Total hasil sekarang: 109.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 237 ✅ Total hasil sekarang: 110.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 238 ✅ Total hasil sekarang: 111.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 239 ✅ Total hasil sekarang: 112.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 240 dilewati ❌ Total hasil sekarang: 112.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 241 dilewati ❌ Total hasil sekarang: 112.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 242 ✅ Total hasil sekarang: 113.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 243 dilewati ❌ Total hasil sekarang: 113.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 244 dilewati ❌ Total hasil sekarang: 113.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 245 ✅ Total hasil sekarang: 114.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 246 ✅ Total hasil sekarang: 115.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 247 dilewati ❌ Total hasil sekarang: 115.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 248 ✅ Total hasil sekarang: 116.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 249 ✅ Total hasil sekarang: 117.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 250 dilewati ❌ Total hasil sekarang: 117.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 251 dilewati ❌ Total hasil sekarang: 117.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 252 ✅ Total hasil sekarang: 118.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 253 ✅ Total hasil sekarang: 119.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 254 ✅ Total hasil sekarang: 120.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 255 ✅ Total hasil sekarang: 121.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 256 ✅ Total hasil sekarang: 122.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 257 ✅ Total hasil sekarang: 123.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 258 dilewati ❌ Total hasil sekarang: 123.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 259 dilewati ❌ Total hasil sekarang: 123.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 260 dilewati ❌ Total hasil sekarang: 123.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 261 dilewati ❌ Total hasil sekarang: 123.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 262 ✅ Total hasil sekarang: 124.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 263 dilewati ❌ Total hasil sekarang: 124.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 264 dilewati ❌ Total hasil sekarang: 124.
# Number of attempts to find similar restaurants by emb: 1
# Number of attempts to find similar restaurants by emb: 2
# Number of attempts to find similar restaurants by emb: 3
# Number of attempts to find similar restaurants by emb: 4
# Number of attempts to find similar restaurants by emb: 5
# Number of attempts to find similar restaurants by emb: 6
# Number of attempts to find similar restaurants by emb: 7
# Number of attempts to find similar restaurants by emb: 8
# Number of attempts to find similar restaurants by emb: 9
# Number of attempts to find similar restaurants by emb: 10
# Data perbandingan kosong, baris 265 dilewati ❌ Total hasil sekarang: 124.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 266 ✅ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 267 dilewati ❌ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 268 dilewati ❌ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 269 dilewati ❌ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 270 dilewati ❌ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 271 dilewati ❌ Total hasil sekarang: 125.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 272 ✅ Total hasil sekarang: 126.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 273 dilewati ❌ Total hasil sekarang: 126.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 274 dilewati ❌ Total hasil sekarang: 126.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 275 ✅ Total hasil sekarang: 127.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 276 ✅ Total hasil sekarang: 128.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 277 dilewati ❌ Total hasil sekarang: 128.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 278 dilewati ❌ Total hasil sekarang: 128.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 279 dilewati ❌ Total hasil sekarang: 128.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 280 ✅ Total hasil sekarang: 129.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 281 ✅ Total hasil sekarang: 130.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 282 ✅ Total hasil sekarang: 131.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 283 dilewati ❌ Total hasil sekarang: 131.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 284 dilewati ❌ Total hasil sekarang: 131.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 285 dilewati ❌ Total hasil sekarang: 131.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 286 dilewati ❌ Total hasil sekarang: 131.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 287 ✅ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 288 dilewati ❌ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 289 dilewati ❌ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 290 dilewati ❌ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 291 dilewati ❌ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 292 dilewati ❌ Total hasil sekarang: 132.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 293 ✅ Total hasil sekarang: 133.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 294 ✅ Total hasil sekarang: 134.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 295 dilewati ❌ Total hasil sekarang: 134.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 296 dilewati ❌ Total hasil sekarang: 134.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 297 ✅ Total hasil sekarang: 135.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 298 ✅ Total hasil sekarang: 136.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 299 ✅ Total hasil sekarang: 137.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 300 ✅ Total hasil sekarang: 138.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 301 ✅ Total hasil sekarang: 139.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 302 dilewati ❌ Total hasil sekarang: 139.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 303 dilewati ❌ Total hasil sekarang: 139.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 304 dilewati ❌ Total hasil sekarang: 139.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 305 dilewati ❌ Total hasil sekarang: 139.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 306 ✅ Total hasil sekarang: 140.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 307 dilewati ❌ Total hasil sekarang: 140.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 308 ✅ Total hasil sekarang: 141.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 309 ✅ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 310 dilewati ❌ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 311 dilewati ❌ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 312 dilewati ❌ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 313 dilewati ❌ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 314 dilewati ❌ Total hasil sekarang: 142.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 315 ✅ Total hasil sekarang: 143.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 316 dilewati ❌ Total hasil sekarang: 143.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 317 dilewati ❌ Total hasil sekarang: 143.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 318 ✅ Total hasil sekarang: 144.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 319 dilewati ❌ Total hasil sekarang: 144.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 320 ✅ Total hasil sekarang: 145.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 321 ✅ Total hasil sekarang: 146.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 322 ✅ Total hasil sekarang: 147.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 323 ✅ Total hasil sekarang: 148.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 324 ✅ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 325 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 326 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 327 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 328 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 329 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 330 dilewati ❌ Total hasil sekarang: 149.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 331 ✅ Total hasil sekarang: 150.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 332 dilewati ❌ Total hasil sekarang: 150.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 333 dilewati ❌ Total hasil sekarang: 150.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 334 dilewati ❌ Total hasil sekarang: 150.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 335 ✅ Total hasil sekarang: 151.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 336 ✅ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 337 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 338 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 339 ✅ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 340 ✅ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 341 ✅ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 342 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 343 ✅ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 344 ✅ Total hasil sekarang: 157.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 345 dilewati ❌ Total hasil sekarang: 157.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 346 dilewati ❌ Total hasil sekarang: 157.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 347 ✅ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 348 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 349 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 350 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 351 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 352 ✅ Total hasil sekarang: 159.
# Number of attempts to find similar restaurants by emb: 1
# ...
# Data perbandingan kosong, baris 2736 dilewati ❌ Total hasil sekarang: 1333.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2737 dilewati ❌ Total hasil sekarang: 1333.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2738 ✅ Total hasil sekarang: 1334.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2739 dilewati ❌ Total hasil sekarang: 1334.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2740 dilewati ❌ Total hasil sekarang: 1334.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2741 dilewati ❌ Total hasil sekarang: 1334.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2742 ✅ Total hasil sekarang: 1335.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2743 ✅ Total hasil sekarang: 1336.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2744 ✅ Total hasil sekarang: 1337.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2745 ✅ Total hasil sekarang: 1338.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2746 ✅ Total hasil sekarang: 1339.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2747 ✅ Total hasil sekarang: 1340.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2748 ✅ Total hasil sekarang: 1341.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2749 ✅ Total hasil sekarang: 1342.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2750 ✅ Total hasil sekarang: 1343.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2751 ✅ Total hasil sekarang: 1344.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2752 dilewati ❌ Total hasil sekarang: 1344.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2753 dilewati ❌ Total hasil sekarang: 1344.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2754 dilewati ❌ Total hasil sekarang: 1344.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2755 ✅ Total hasil sekarang: 1345.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2756 dilewati ❌ Total hasil sekarang: 1345.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2757 ✅ Total hasil sekarang: 1346.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2758 dilewati ❌ Total hasil sekarang: 1346.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2759 dilewati ❌ Total hasil sekarang: 1346.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2760 ✅ Total hasil sekarang: 1347.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2761 dilewati ❌ Total hasil sekarang: 1347.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2762 dilewati ❌ Total hasil sekarang: 1347.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2763 dilewati ❌ Total hasil sekarang: 1347.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2764 ✅ Total hasil sekarang: 1348.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2765 dilewati ❌ Total hasil sekarang: 1348.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2766 dilewati ❌ Total hasil sekarang: 1348.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2767 ✅ Total hasil sekarang: 1349.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2768 ✅ Total hasil sekarang: 1350.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2769 ✅ Total hasil sekarang: 1351.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2770 ✅ Total hasil sekarang: 1352.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2771 dilewati ❌ Total hasil sekarang: 1352.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2772 ✅ Total hasil sekarang: 1353.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2773 ✅ Total hasil sekarang: 1354.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2774 ✅ Total hasil sekarang: 1355.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2775 ✅ Total hasil sekarang: 1356.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2776 dilewati ❌ Total hasil sekarang: 1356.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2777 ✅ Total hasil sekarang: 1357.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2778 dilewati ❌ Total hasil sekarang: 1357.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2779 ✅ Total hasil sekarang: 1358.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2780 dilewati ❌ Total hasil sekarang: 1358.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2781 dilewati ❌ Total hasil sekarang: 1358.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2782 dilewati ❌ Total hasil sekarang: 1358.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2783 ✅ Total hasil sekarang: 1359.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2784 ✅ Total hasil sekarang: 1360.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2785 dilewati ❌ Total hasil sekarang: 1360.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2786 ✅ Total hasil sekarang: 1361.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2787 dilewati ❌ Total hasil sekarang: 1361.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2788 ✅ Total hasil sekarang: 1362.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2789 ✅ Total hasil sekarang: 1363.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2790 ✅ Total hasil sekarang: 1364.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2791 dilewati ❌ Total hasil sekarang: 1364.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2792 ✅ Total hasil sekarang: 1365.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2793 ✅ Total hasil sekarang: 1366.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2794 ✅ Total hasil sekarang: 1367.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2795 ✅ Total hasil sekarang: 1368.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2796 dilewati ❌ Total hasil sekarang: 1368.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2797 dilewati ❌ Total hasil sekarang: 1368.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2798 ✅ Total hasil sekarang: 1369.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2799 ✅ Total hasil sekarang: 1370.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2800 ✅ Total hasil sekarang: 1371.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2801 ✅ Total hasil sekarang: 1372.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2802 dilewati ❌ Total hasil sekarang: 1372.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2803 dilewati ❌ Total hasil sekarang: 1372.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2804 dilewati ❌ Total hasil sekarang: 1372.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2805 ✅ Total hasil sekarang: 1373.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2806 ✅ Total hasil sekarang: 1374.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2807 ✅ Total hasil sekarang: 1375.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2808 ✅ Total hasil sekarang: 1376.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2809 ✅ Total hasil sekarang: 1377.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2810 dilewati ❌ Total hasil sekarang: 1377.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2811 dilewati ❌ Total hasil sekarang: 1377.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2812 dilewati ❌ Total hasil sekarang: 1377.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2813 ✅ Total hasil sekarang: 1378.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2814 dilewati ❌ Total hasil sekarang: 1378.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2815 dilewati ❌ Total hasil sekarang: 1378.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2816 ✅ Total hasil sekarang: 1379.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2817 ✅ Total hasil sekarang: 1380.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2818 ✅ Total hasil sekarang: 1381.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2819 ✅ Total hasil sekarang: 1382.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2820 dilewati ❌ Total hasil sekarang: 1382.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2821 ✅ Total hasil sekarang: 1383.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2822 ✅ Total hasil sekarang: 1384.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2823 dilewati ❌ Total hasil sekarang: 1384.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2824 ✅ Total hasil sekarang: 1385.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2825 dilewati ❌ Total hasil sekarang: 1385.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2826 ✅ Total hasil sekarang: 1386.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2827 dilewati ❌ Total hasil sekarang: 1386.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2828 dilewati ❌ Total hasil sekarang: 1386.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2829 dilewati ❌ Total hasil sekarang: 1386.
# Number of attempts to find similar restaurants by emb: 1
# Data valid ditemukan dan ditambahkan pada baris 2830 ✅ Total hasil sekarang: 1387.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2831 dilewati ❌ Total hasil sekarang: 1387.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2832 dilewati ❌ Total hasil sekarang: 1387.
#       index                restaurant  \
# 0         6  'BUKAN SEMBARANG CIRENG'
# 1         7                         -
# 2        10                        23
# 3        12                   3M Food
# 4        15                        99
# ...     ...                       ...
# 1382   2820           tahu susu aulia
# 1383   2821       tela tela mpu purwa
# 1384   2823       telur gulung mak ti
# 1385   2825             teras kuliner
# 1386   2829                   yuk tri
#
#                                                    menu              city  \
# 0                                         [CIRENG BEKU]            Malang
# 1     [Buntut Sapi, Daging Sapi, Jerohan Sapi, Kepal...  KAB. PROBOLINGGO
# 2                               [BIHUN TELUR GULUNG 23]            Malang
# 3          [Dimsum Udang, Mie Pangsit, Tahu Bakso Ayam]            Malang
# 4     [Kulit Pangsit 99, MIE BASAH 99, Kulit pangsit...            Malang
# ...                                                 ...               ...
# 1382                                  [tahu susu aulia]            Malang
# 1383                                [tela tela, cimol ]            Malang
# 1384           [telur gulung, nasi goreng, pisang keju]  Kabupaten Gresik
# 1385  [asam manis ikan mas, es timun, ayam bakar, ja...  Kabupaten Gresik
# 1386       [kue nastar, kue kastengel, kue putri salju]            Malang
#
#            comp_restaurant                                          comp_menu  \
# 0     Aneka Gorengan Siaga  [bakwan Sayur, tempe Crispi, tahu Jeletot, tah...
# 1             Bebek NdoWer  [Jaer Nila, Es Jeruk Manis, Nasi Bebek Mumer, ...
# 2              Copa Coffee  [Milo, Nanas, Nasi Goreng Ikan Asin, Iced Tea,...
# 3                Mie Jeder  [Mie Pedas Jeder Rendang Level 1, Mie Pedas Je...
# 4        SEBLAK BANDUNG 86  [Seblak Baso Ikan, Es Milo, Seblak Spesial Sup...
# ...                    ...                                                ...
# 1382         Pancong Pijay  [Pancong Ovaltine Keju Susu, Ropang Pisang Kej...
# 1383         Kedai ReffTwo  [Nasi Ayam Pop Cron, Mie Seblak ReffTwo, Boba ...
# 1384          Warung Teguh  [Bakso Bakar Dan Tahu Bakar, Tela Tela, Tahu W...
# 1385               Subsidi  [Telur Dadar, Es Teh Manis, Mie Goreng, Nasi G...
# 1386     Gorengan Bu Aidah  [Risol Goreng, Bakwan Goreng, Kue Lapis, Godok...
#
#          score     status
# 0     0.055556  overclaim
# 1     0.043478  overclaim
# 2     0.016393  overclaim
# 3     0.333333       aman
# 4     0.066667  overclaim
# ...        ...        ...
# 1382  0.030303  overclaim
# 1383  0.025000  overclaim
# 1384  0.222222  overclaim
# 1385  0.142857  overclaim
# 1386  0.100000  overclaim
#
# [1387 rows x 8 columns]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
df_hasil.to_excel("df_hasil_1kata_1387_rows_512dim.xlsx")
