# %%
import pandas as pd
from neo4j import GraphDatabase
from time import sleep
from random import randint
from langchain_ollama.llms import OllamaLLM
import ast
# Import json untuk parsing output LLM
import json

# %%
# 0. Configuration
# -----------------------------------------------------------------------------
# Define Host & Port
OLLAMA_HOST = "127.0.0.1"
OLLAMA_PORT = 11435

# CONFIG IMPORTANT PARAMETERS
MODEL_LLAMA = "deepseek-r1:8b"

TEMPERATURE = 0.75

# Define Model
try:
    llm = OllamaLLM(
        model=MODEL_LLAMA,
        base_url=f"http://{OLLAMA_HOST}:{OLLAMA_PORT}",
        verbose=False,
        temperature=TEMPERATURE
    )
    # Test connection
    llm.invoke("Hello")
    print(f"--- Koneksi Ollama ke model '{MODEL_LLAMA}' berhasil ---")
except Exception as e:
    print(f"--- Gagal terhubung ke Ollama ---")
    print(f"Error: {e}")
    print(f"Pastikan Ollama berjalan di {OLLAMA_HOST}:{OLLAMA_PORT} dan model '{MODEL_LLAMA}' tersedia.")
# Out:
# --- Koneksi Ollama ke model 'deepseek-r1:8b' berhasil ---

# %%
# 1. Load CSV file and convert 'menu' and 'embedding' to list
# -----------------------------------------------------------------------------
df = pd.read_csv('wave_emb_dbmcv2.csv')
df = df.drop(['Unnamed: 0'], axis=1)
print(f"Tipe data nilai pada kolom 'menu' sebelum konversi: {type(df['menu'][0])}\nTipe data nilai pada kolom 'embedding' sebelum konversi: {type(df['embedding'][0])}")
df['menu'] = df['menu'].apply(ast.literal_eval)
df['embedding'] = df['embedding'].apply(ast.literal_eval)
print(f"Tipe data nilai pada kolom 'menu' setelah konversi: {type(df['menu'][0])}\nTipe data nilai pada kolom 'embedding' setelah konversi: {type(df['embedding'][0])}")
df
# Out:
# Tipe data nilai pada kolom 'menu' sebelum konversi: <class 'str'>
# Tipe data nilai pada kolom 'embedding' sebelum konversi: <class 'str'>
# Tipe data nilai pada kolom 'menu' setelah konversi: <class 'list'>
# Tipe data nilai pada kolom 'embedding' setelah konversi: <class 'list'>
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2827                                   virinda food
# 2828                                       wouwcake
# 2829                                        yuk tri
# 2830                                           zara
# 2831  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu              city  \
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...          Surabaya
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...  Kabupaten Gresik
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...            Malang
# 3                            [KRUPUK BAWANG RANIS KDS ]            Malang
# 4                         [Kacang Goreng Winarti Snack]          Surabaya
# ...                                                 ...               ...
# 2827                                   [Rolade, Sempol]            Malang
# 2828  [risoles wouwcake, kue tar wouwcake, kroket ke...          Surabaya
# 2829       [kue nastar, kue kastengel, kue putri salju]            Malang
# 2830                                   [stik keju zara]            Malang
# 2831                 [Tape Ketan Kartika Khas Kuningan]        Kota Depok
#
#                                alt_resto  \
# 0                       ['Dapur Fizzul']
# 1            ['Rawon Balungan H. Mufid']
# 2                        ['Sambat Luwe']
# 3           ['KDS Cantonese Restaurant']
# 4               ['Nathania Snack House']
# ...                                  ...
# 2827                  ['Javanine Resto']
# 2828           ['Warung wong lue (WWL)']
# 2829                  ['Trimurti Resto']
# 2830       ['Lafayette Coffee & Eatery']
# 2831  ['Tape Ketan Putih Khas Kuningan']
#
#                                               embedding
# 0     [[-0.02187000773847103, 0.01127985492348671, -...
# 1     [[0.01963287591934204, 0.056399986147880554, 0...
# 2     [[0.009273191913962364, 0.03742887079715729, -...
# 3     [[-0.08321938663721085, 0.05083480849862099, 0...
# 4     [[-0.09416132420301437, 0.10255325585603714, 0...
# ...                                                 ...
# 2827  [[-0.024130970239639282, 0.0011671549873426557...
# 2828  [[-0.03364633023738861, 0.07875539362430573, -...
# 2829  [[-0.010088230483233929, -0.05614767223596573,...
# 2830  [[0.004909013397991657, -0.049723122268915176,...
# 2831  [[-0.002083861967548728, 0.04289808124303818, ...
#
# [2832 rows x 5 columns]

# %%
# 2. Neo4j connection & similarity helpers
# -----------------------------------------------------------------------------
drv = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))

def find_similar_restaurants_by_embedding(alts_embs: list[list[float]], threshold=0.6, topk=2):
    ids = []
    with drv.session() as ses:
        for emb in alts_embs:
            # Kueri ini mengembalikan properti 'r_id' dari node
            rows = ses.run("""
                CALL db.index.vector.queryNodes('restaurant_emb_dbmcv2', $topk, $emb)
                YIELD node, score
                WHERE score >= $threshold
                OPTIONAL MATCH (other:Restaurant)-[s:SIMILAR_TO_DBMCV2]->(node)
                    WHERE s.score >= $threshold
                RETURN DISTINCT node.r_id AS id, collect(other.r_id) AS linked_ids
                """, emb=emb, threshold=threshold, topk=topk)
            for r in rows:
                if r["id"] is not None:
                    ids.append(r["id"])
                ids.extend(r["linked_ids"])
    return list(set(ids))

# Fungsi jaccard menerima list berisi string
def jaccard(list1: list[str], list2: list[str]) -> float:
    """Menghitung Jaccard similarity antara dua list string."""
    set1 = {item.lower().strip() for item in list1}
    set2 = {item.lower().strip() for item in list2}
    
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    
    return intersection / union if union != 0 else 0.0

# %%
# 3. Overclaim checker
# -----------------------------------------------------------------------------
def check_overclaim(menu_names: list[str], alts_embs: list[list[float]]):
    # 1) look up their node IDs in Neo4j (Tidak ada perubahan)
    rids_count = 1
    for i in range(10):
        rids = find_similar_restaurants_by_embedding(alts_embs)
        print(f"Number of attempts to find similar restaurants by emb: {rids_count}")
        if rids: break
        rids_count += 1
        sleep(randint(1, 2))

    # Jika tidak ada kandidat ditemukan, keluar lebih awal
    if not rids:
        return [], 0.0, None, [], [], []
    
    # 2) Kumpulkan semua kandidat dan menu mereka dari Neo4j terlebih dahulu
    candidates = []
    with drv.session() as ses:
        for rid in rids:
            result = ses.run(
                """
                MATCH (r:Restaurant {r_id:$rid})
                OPTIONAL MATCH (r)-[:HAS_PRODUCT]->(m:Menu)
                RETURN r.restaurant AS restaurant_name, collect(m.menu) AS actual_menus
                """, rid=rid
            )
            rec = result.single()
            if rec and rec["restaurant_name"]:
                candidates.append({
                    "id": rid,
                    "name": rec["restaurant_name"],
                    "menu": rec["actual_menus"]
                })

    # Jika setelah query tidak ada kandidat valid, keluar
    if not candidates:
        return [], 0.0, None, [], [], []

    # 3) Cari kandidat terbaik menggunakan Jaccard similarity (perhitungan "murah")
    best_candidate = None
    max_jaccard_score = 0.0
    for cand in candidates:
        score = jaccard(cand["menu"], menu_names)
        if score > max_jaccard_score:
            max_jaccard_score = score
            best_candidate = cand
            
    # Jika tidak ada menu yang cocok sama sekali
    if not best_candidate:
        return [], 0.0, None, [], [], []

    # 4) Lakukan satu panggilan LLM untuk generalisasi pada kandidat terbaik
    gen_menu_names = menu_names
    gen_actual_menus = best_candidate["menu"]
    
    prompt_list1 = list(set(menu_names))
    prompt_list2 = list(set(best_candidate["menu"]))

    prompt_template_generalize = f"""
    Anda adalah asisten cerdas untuk generalisasi menu. Saya memiliki dua list menu:

    List 1: {prompt_list1}

    List 2: {prompt_list2}

    Tugas Anda:
    1. Anggap setiap list sebagai set (abaikan duplikat internal).
    2. Generalisasikan setiap item dalam set ke kategori makanan intinya menggunakan pengetahuan makanan Anda.
    3. Kembalikan hasil dalam Bahasa Indonesia dan format JSON yang ketat dengan kunci "gen_menu" (untuk List 1) dan "gen_comp_menu" (untuk List 2).

    Gunakan contoh-contoh berikut sebagai panduan ketat untuk generalisasi:
    
    Contoh Input A:
    Daftar 1: ["Bolu Pisang", "Brownies Kukus Besar", "Brownies Chocochip", "Gurame"]
    Daftar 2: ["Bolu Gulung Durian", "Patin", "Es Teh Manis", "Lele Goreng"]
    
    Contoh Output JSON A:
    {{
      "gen_menu": ["bolu", "brownies", "ikan"],
      "gen_comp_menu": ["bolu", "ikan", "teh"]
    }}

    Contoh Input B:
    Daftar 1: ["Ayam Goreng", "Ayam Bakar", "Brownies", "Kopi Hitam Hangat", "Pisang Goreng"]
    Daftar 2: ["Fried Chicken", "Fried Duck", "Bika Ambon", "Caramel Latte", "Cappuccino", "Gurame"]
    
    Contoh Output JSON B:
    {{
      "gen_menu": ["ayam", "kue", "kopi", "pisang"],
      "gen_comp_menu": ["ayam", "bebek", "kue", "kopi", "ikan"]
    }}

    Contoh Input C:
    Daftar 1: ["Fish Tofu", "Ramen"]
    Daftar 2: ["Tahu Kuning", "Tempe", "Indomie Telor"]
    
    Contoh Output JSON C:
    {{
      "gen_menu": ["tahu", "mie"],
      "gen_comp_menu": ["tahu", "tempe", "mie"]
    }}

    Contoh Input D:
    Daftar 1: ["Nasi Uduk", "Cumi-cumi Asam Manis", "Udang", "Telor Balado"]
    Daftar 2: ["Seafood Fried Rice", "Cumi Goreng Tepung", "Lobster", "Omelette"]
    
    Contoh Output JSON D:
    {{
      "gen_menu": ["nasi", "cumi", "udang", "telur"],
      "gen_comp_menu": ["nasi", "cumi", "lobster", "telur"]
    }}

    Contoh Input E:
    Daftar 1: ["Nasi Putih", "Nasi Uduk", "Lalapan", "Sambel Merah", "Sambel Ijo"]
    Daftar 2: ["Nasi Kuning", "Ayam Goreng", "Bebek Goreng", "Rendang Sapi", "Rawon Sapi", "Tengkleng", "Sate Kambing", "Sambal"]
    
    Contoh Output JSON E:
    {{
      "gen_menu": ["nasi", "lalapan", "sambal"],
      "gen_comp_menu": ["nasi", "ayam", "bebek", "sapi", "kambing", "sambal"]
    }}
    
    Output JSON Anda:
    """

    print("\nMeminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (hanya sekali)...")
    try:
        response = llm.invoke(prompt_template_generalize)
        
        # OllamaLLM (base LLM) mengembalikan string
        response_content = response.strip() 
        
        if response_content.startswith("```json"):
            response_content = response_content[7:-3].strip()
        elif response_content.startswith("```"):
            response_content = response_content[3:-3].strip()

        data = json.loads(response_content)
        
        gen_menu_names = data.get("gen_menu", menu_names)
        gen_actual_menus = data.get("gen_comp_menu", best_candidate["menu"])
        print(f"✅ Generalisasi LLM (Ollama) berhasil.")

    except Exception as e:
        print(f"⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): {e}. Menggunakan menu asli untuk Jaccard.")
    
    # 5) Hitung skor Jaccard final berdasarkan hasil generalisasi
    final_score = jaccard(gen_actual_menus, gen_menu_names)

    issues = []
    if final_score < 0.3:
        issues.append({
            "restaurant_id": best_candidate["id"],
            "restaurant_name": best_candidate["name"],
            "jaccard_score": final_score
        })

    return issues, final_score, best_candidate["name"], best_candidate["menu"], gen_menu_names, gen_actual_menus

# Fungsi evaluate_row mengembalikan tuple dengan menu generalisasi
def evaluate_row(menus: list[str], emb: list[list[float]]) -> tuple[str, float, str | None, list[str], list[str], list[str]]:
    """
    Mengevaluasi satu baris data, menentukan status berdasarkan Jaccard score akhir.
    """
    # Tangkap semua nilai yang dikembalikan oleh check_overclaim
    issues, score, comp_name, comp_menu, gen_menu, gen_comp_menu = check_overclaim(menus, emb)
    
    status = "overclaim" if score < 0.3 else "aman"
    
    # Kembalikan semua data yang relevan termasuk menu generalisasi
    return status, score, comp_name, comp_menu, gen_menu, gen_comp_menu

# %%
# 4. Run on the "df" DataFrame
# -----------------------------------------------------------------------------
hasil = []
# Looping menangani score, data perbandingan, dan menu generalisasi
for idx, row in df.iterrows():
    # Tangkap semua nilai yang dikembalikan oleh evaluate_row
    status, score, comp_restaurant, comp_menu, gen_menu, gen_comp_menu = evaluate_row(row["menu"], row["embedding"])
    
    # Kondisi untuk append
    # Hanya tambahkan ke 'hasil' jika 'comp_restaurant' DAN 'comp_menu' tidak kosong.
    if comp_restaurant and comp_menu:
        hasil.append({
            "index": idx,
            "restaurant": row["restaurant"],
            "menu": row["menu"],
            "city": row["city"],
            "comp_restaurant": comp_restaurant,
            "comp_menu": comp_menu,
            # Tambahkan kolom menu yang sudah digeneralisasi
            "gen_menu": gen_menu,
            "gen_comp_menu": gen_comp_menu,
            "score": score,
            "status": status
        })
        print(f"Data valid ditemukan dan ditambahkan pada baris {idx+1} ✅ Total hasil sekarang: {len(hasil)}.")
    else:
        print(f"Data perbandingan kosong, baris {idx+1} dilewati ❌ Total hasil sekarang: {len(hasil)}.")

df_hasil = pd.DataFrame(hasil)
df_hasil
# Out:
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 1 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 3 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 4 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 5 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 6 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 7 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 8 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 9 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 10 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 11 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 12 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 13 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 14 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 15 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 16 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 17 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 18 dilewati ❌ Total hasil sekarang: 0.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 3 column 14564 (char 14597). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 19 ✅ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 20 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 21 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 22 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 23 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 24 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 25 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 26 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 27 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 28 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 29 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 30 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 31 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 32 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 33 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 34 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 35 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 36 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 37 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 38 dilewati ❌ Total hasil sekarang: 1.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 39 ✅ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 40 dilewati ❌ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 41 dilewati ❌ Total hasil sekarang: 2.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 42 ✅ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 43 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 44 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 45 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 46 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 47 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 48 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 49 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 50 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 51 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 52 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 53 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 54 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 55 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 56 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 57 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 58 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 59 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 60 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 61 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 62 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 63 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 64 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 65 dilewati ❌ Total hasil sekarang: 3.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 66 ✅ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 67 dilewati ❌ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 68 dilewati ❌ Total hasil sekarang: 4.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 69 ✅ Total hasil sekarang: 5.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 70 dilewati ❌ Total hasil sekarang: 5.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 71 dilewati ❌ Total hasil sekarang: 5.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 72 dilewati ❌ Total hasil sekarang: 5.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 73 ✅ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 74 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 75 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 76 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 77 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 78 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 79 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 80 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 81 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 82 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 83 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 84 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 85 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 86 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 87 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 88 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 89 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 90 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 91 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 92 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 93 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 94 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 95 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 96 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 97 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 98 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 99 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 100 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 101 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 102 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 103 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 104 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 105 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 106 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 107 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 108 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 109 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 110 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 111 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 112 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 113 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 114 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 115 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 116 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 117 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 118 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 119 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 120 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 121 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 122 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 123 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 124 dilewati ❌ Total hasil sekarang: 6.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 125 ✅ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 126 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 127 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 128 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 129 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 130 dilewati ❌ Total hasil sekarang: 7.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 131 ✅ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 132 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 133 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 134 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 135 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 136 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 137 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 138 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 139 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 140 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 141 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 142 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 143 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 144 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 145 dilewati ❌ Total hasil sekarang: 8.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 146 ✅ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 147 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 148 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 149 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 150 dilewati ❌ Total hasil sekarang: 9.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 151 ✅ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 152 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 153 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 154 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Number of attempts to find similar restaurants by emb: 2
# Number of attempts to find similar restaurants by emb: 3
# Number of attempts to find similar restaurants by emb: 4
# Number of attempts to find similar restaurants by emb: 5
# Number of attempts to find similar restaurants by emb: 6
# Number of attempts to find similar restaurants by emb: 7
# Number of attempts to find similar restaurants by emb: 8
# Number of attempts to find similar restaurants by emb: 9
# Number of attempts to find similar restaurants by emb: 10
# Data perbandingan kosong, baris 155 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 156 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 157 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 158 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 159 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 160 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 161 dilewati ❌ Total hasil sekarang: 10.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 162 ✅ Total hasil sekarang: 11.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 163 ✅ Total hasil sekarang: 12.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 164 dilewati ❌ Total hasil sekarang: 12.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 165 ✅ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 166 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 167 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 168 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 169 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 170 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 171 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 172 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 173 dilewati ❌ Total hasil sekarang: 13.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 174 ✅ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 175 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 176 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 177 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 178 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 179 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 180 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 181 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 182 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 183 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 184 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 185 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 186 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 187 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 188 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 189 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 190 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 191 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 192 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 193 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 194 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 195 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 196 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 197 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 198 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 199 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 200 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 201 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 202 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 203 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 204 dilewati ❌ Total hasil sekarang: 14.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 205 ✅ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 206 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 207 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 208 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 209 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 210 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 211 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 212 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 213 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 214 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 215 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 216 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 217 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 218 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 219 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 220 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 221 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 222 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 223 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 224 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 225 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 226 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 227 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 228 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 229 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 230 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 231 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 232 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 233 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 234 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 235 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 236 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 237 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 238 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 239 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 240 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 241 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 242 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 243 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 244 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 245 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 246 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 247 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 248 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 249 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 250 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 251 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 252 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 253 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 254 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 255 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 256 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 257 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 258 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 259 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 260 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 261 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 262 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 263 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 264 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Number of attempts to find similar restaurants by emb: 2
# Number of attempts to find similar restaurants by emb: 3
# Number of attempts to find similar restaurants by emb: 4
# Number of attempts to find similar restaurants by emb: 5
# Number of attempts to find similar restaurants by emb: 6
# Number of attempts to find similar restaurants by emb: 7
# Number of attempts to find similar restaurants by emb: 8
# Number of attempts to find similar restaurants by emb: 9
# Number of attempts to find similar restaurants by emb: 10
# Data perbandingan kosong, baris 265 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 266 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 267 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 268 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 269 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 270 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 271 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 272 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 273 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 274 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 275 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 276 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 277 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 278 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 279 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 280 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 281 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 282 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 283 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 284 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 285 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 286 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 287 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 288 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 289 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 290 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 291 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 292 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 293 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 294 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 295 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 296 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 297 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 298 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 299 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 300 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 301 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 302 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 303 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 304 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 305 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 306 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 307 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 308 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 309 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 310 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 311 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 312 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 313 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 314 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 315 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 316 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 317 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 318 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 319 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 320 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 321 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 322 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 323 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 324 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 325 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 326 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 327 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 328 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 329 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 330 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 331 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 332 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 333 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 334 dilewati ❌ Total hasil sekarang: 15.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 335 ✅ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 336 dilewati ❌ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 337 dilewati ❌ Total hasil sekarang: 16.
# Number of attempts to find similar restaurants by emb: 1
# ...
# Data perbandingan kosong, baris 2756 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2757 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2758 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2759 dilewati ❌ Total hasil sekarang: 152.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 2760 ✅ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2761 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2762 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2763 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2764 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2765 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2766 dilewati ❌ Total hasil sekarang: 153.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 2767 ✅ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2768 dilewati ❌ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2769 dilewati ❌ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2770 dilewati ❌ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2771 dilewati ❌ Total hasil sekarang: 154.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 2772 ✅ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2773 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2774 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2775 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2776 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2777 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2778 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2779 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2780 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2781 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2782 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2783 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2784 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2785 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2786 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2787 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2788 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2789 dilewati ❌ Total hasil sekarang: 155.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 2790 ✅ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2791 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2792 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2793 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2794 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2795 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2796 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2797 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2798 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2799 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2800 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2801 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2802 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2803 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2804 dilewati ❌ Total hasil sekarang: 156.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 2805 ✅ Total hasil sekarang: 157.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2806 dilewati ❌ Total hasil sekarang: 157.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ⚠️ Gagal menggeneralisasi menu dari LLM (Ollama): Expecting value: line 1 column 1 (char 0). Menggunakan menu asli untuk Jaccard.
# Data valid ditemukan dan ditambahkan pada baris 2807 ✅ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2808 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2809 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2810 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2811 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2812 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2813 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2814 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2815 dilewati ❌ Total hasil sekarang: 158.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 2816 ✅ Total hasil sekarang: 159.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2817 dilewati ❌ Total hasil sekarang: 159.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2818 dilewati ❌ Total hasil sekarang: 159.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 2819 ✅ Total hasil sekarang: 160.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2820 dilewati ❌ Total hasil sekarang: 160.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2821 dilewati ❌ Total hasil sekarang: 160.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2822 dilewati ❌ Total hasil sekarang: 160.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2823 dilewati ❌ Total hasil sekarang: 160.
# Number of attempts to find similar restaurants by emb: 1
#
# 🤖 Meminta LLM (Ollama) untuk menggeneralisasi menu secara semantik (HANYA SEKALI)...
# ✅ Generalisasi LLM (Ollama) berhasil.
# Data valid ditemukan dan ditambahkan pada baris 2824 ✅ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2825 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2826 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2827 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2828 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2829 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2830 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2831 dilewati ❌ Total hasil sekarang: 161.
# Number of attempts to find similar restaurants by emb: 1
# Data perbandingan kosong, baris 2832 dilewati ❌ Total hasil sekarang: 161.
#      index                               restaurant  \
# 0       18                   A & F Cake and Cookies
# 1       38                                   AICIRO
# 2       41                                AIRLANGGA
# 3       65  ANEKA MINUMAN (DHARMAWANITA – SUMIYATI)
# 4       68                 ANGKRINGAN RINGIN KURUNG
# ..     ...                                      ...
# 156   2804                                 mie kuah
# 157   2806                  minuman segar jaya guna
# 158   2815                            roti bakar 51
# 159   2818                               sri rejeki
# 160   2823                      telur gulung mak ti
#
#                                                   menu              city  \
# 0    [Kue Kastengel, Kue Kacang, Kue Stik Keju, Donat]            Malang
# 1    [\tCHOCO CARAMEL, \tJASMINE TEA, \tMANGO BOBA ...       KOTA MALANG
# 2    [Burger, Burger + Keju, Kebab, Kentang Goreng,...     Kota Surabaya
# 3    [Air Mineral, Es Cincau, Es Degan, Es Gooday (...     Kota Surabaya
# 4    [DUMPLING BAKAR, BAKSO BAKAR, TELUR PUYUH BAKA...            Malang
# ..                                                 ...               ...
# 156  [mie kuah, gimbal tempe, ote-ote, mie goreng, ...  Kabupaten Gresik
# 157      [temulawak, sinom, beras kencur, kunyit asam]  Kabupaten Gresik
# 158  [roti bakar, ROTI BAKAR BANDUNG, ROTI BAKAR BA...            Malang
# 159  [ote- ote sri rejeki, pisang goreng, tempe isi...            Malang
# 160           [telur gulung, nasi goreng, pisang keju]  Kabupaten Gresik
#
#            comp_restaurant                                          comp_menu  \
# 0     Raihan Bakery, Denai  [Tawar (Ceres/Keju), Bolu Gulung Chocomaltine,...
# 1              Jajan Toast  [Choco Banana, Dimsum Campur ( 4 variant Dimsu...
# 2            Assalam Resto  [Sop Ikan Gurame/Nila, Gurame/Nila Saos Padang...
# 3         Kedai Es Juragan  [Jus Melon, Jahe Merah, Es Nutrisari, Jus Sirs...
# 4    Angkringan Abas Krian  [Koin Kornet, Kepala Ayam, Sate Usus Bakar, Es...
# ..                     ...                                                ...
# 156    Sari Rasa, Mojosari  [Angsio Hibien, Nasi Cap Jay, Kwetiau Goreng, ...
# 157        Warung Sego BHS  [Beras Kencur, Krupuk Puli, Teh Hangat, Juice ...
# 158       Bakso Bakar Hot   [Telur Gulung Nuget, Tahu Walek Bakso Crispi, ...
# 159   Aneka Gorengan Siaga  [bakwan Sayur, tempe Crispi, tahu Jeletot, tah...
# 160           Warung Teguh  [Bakso Bakar Dan Tahu Bakar, Tela Tela, Tahu W...
#
#                                               gen_menu  \
# 0    [Kue Kastengel, Kue Kacang, Kue Stik Keju, Donat]
# 1    [\tCHOCO CARAMEL, \tJASMINE TEA, \tMANGO BOBA ...
# 2    [Burger, Burger + Keju, Kebab, Kentang Goreng,...
# 3                           [es, minuman, jeruk, nata]
# 4    [DUMPLING BAKAR, BAKSO BAKAR, TELUR PUYUH BAKA...
# ..                                                 ...
# 156  [mie kuah, gimbal tempe, ote-ote, mie goreng, ...
# 157      [temulawak, sinom, beras kencur, kunyit asam]
# 158                                             [roti]
# 159                               [pisang, ote, tempe]
# 160                              [nasi, telur, pisang]
#
#                                          gen_comp_menu     score     status
# 0    [Tawar (Ceres/Keju), Bolu Gulung Chocomaltine,...  0.007463  overclaim
# 1    [Choco Banana, Dimsum Campur ( 4 variant Dimsu...  0.035088  overclaim
# 2    [Sop Ikan Gurame/Nila, Gurame/Nila Saos Padang...  0.023256  overclaim
# 3    [es, minuman, jeruk, nata, cokelat, tahu, sapi...  0.400000       aman
# 4    [Koin Kornet, Kepala Ayam, Sate Usus Bakar, Es...  0.019608  overclaim
# ..                                                 ...       ...        ...
# 156  [Angsio Hibien, Nasi Cap Jay, Kwetiau Goreng, ...  0.058824  overclaim
# 157  [Beras Kencur, Krupuk Puli, Teh Hangat, Juice ...  0.153846  overclaim
# 158  [roti, sosis, bakso, burger, pisang, tahu, uda...  0.083333  overclaim
# 159  [pisang, singkong, tempe, tahu, ceker, bakso, ...  0.125000  overclaim
# 160            [bakso, tahu, roti, mie, pisang, telur]  0.285714  overclaim
#
# [161 rows x 10 columns]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_hasil.to_excel("df_hasil_semantik_161_baris_deepseek-r1-8b_temp0-75_512dim.xlsx")
