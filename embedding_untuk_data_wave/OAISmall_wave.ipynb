# %%
import os
from dotenv import load_dotenv, find_dotenv
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings

# Impor yang diperlukan untuk Google Maps API
import requests
import urllib.parse

# %%
# 0. Configuration
# -----------------------------------------------------------------------------
_ = load_dotenv(find_dotenv()) # baca file .env lokal
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]
Maps_API_KEY = os.environ["Maps_API_KEY"]

llm = ChatOpenAI(
    temperature=0,
    model="gpt-4o-mini",
    openai_api_key=OPENAI_API_KEY
)
print("Model ChatOpenAI (LLM) berhasil dimuat.")

# Inisialisasi embedder
embedder = OpenAIEmbeddings(model="text-embedding-3-small", api_key=OPENAI_API_KEY)
print("Model OpenAIEmbeddings berhasil dimuat.")
# Out:
# Model ChatOpenAI (LLM) berhasil dimuat.
# C:\Users\ganendraaby\AppData\Local\Temp\ipykernel_7360\3729896343.py:16: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embedder = OpenAIEmbeddings(model="text-embedding-3-small", api_key=OPENAI_API_KEY)
# Model OpenAIEmbeddings berhasil dimuat.

# %%
# 1. Define Google Maps and LLM Tools
# -----------------------------------------------------------------------------
# 1) Mendefinisikan Tool Google Maps
def Maps_search(query: str) -> str:
    """
    Menjalankan pencarian pada Google Maps Places API dan mengembalikan
    hasil yang diformat dengan baik.
    """
    api_key = Maps_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

    full_url = f"{base_url}query={urllib.parse.quote(query)}&key={api_key}"

    try:
        response = requests.get(full_url)
        response.raise_for_status()
        data = response.json()

        results = data.get("results", [])
        if not results:
            return "Tidak ada hasil yang ditemukan."

        # Ambil hingga 3 hasil untuk memberikan konteks yang lebih baik ke LLM
        formatted_results = []
        for place in results[:3]:
            name = place.get('name')
            address = place.get('formatted_address')
            formatted_results.append(f"Nama: {name}, Alamat: {address}")

        return "\n".join(formatted_results)

    except requests.exceptions.RequestException as e:
        return f"Error saat memanggil Google Maps API: {e}"
    except Exception as e:
        return f"Terjadi kesalahan tak terduga: {e}"

# 2) Mendefinisikan Tool LLM
def get_similar_restaurants(restaurant_name: str, location: str) -> list[str]:
    """
    Mencari restoran serupa menggunakan Google Maps, kemudian meminta LLM
    untuk mengekstrak nama dari hasil pencarian tersebut.
    """
    # Langkah 1: Memanggil Google Maps tool secara langsung untuk mendapatkan data.
    print(f"🔍 Mencari data di Google Maps untuk: 'restoran mirip {restaurant_name} di {location}'")
    search_query = f"restoran dengan nama mirip {restaurant_name} di {location}"
    maps_data = Maps_search(search_query)
    print(f"📝 Data dari Maps:\n---\n{maps_data}\n---")

    if "Tidak ada hasil" in maps_data or "Error" in maps_data:
        return [maps_data]

    # Langkah 2: Membuat prompt untuk LLM dengan menyertakan data dari Maps.
    prompt_template = f"""
    Berdasarkan data pencarian Google Maps berikut:
    \"\"\"
    {maps_data}
    \"\"\"

    Sebutkan HANYA NAMA dari restoran yang paling mirip dengan nama '{restaurant_name}'.
    Tuliskan SATU NAMA restoran saja. Jangan sertakan alamat atau kata-kata tambahan.
    """

    # Langkah 3: Memanggil LLM dengan prompt yang sudah berisi data.
    print("\n🧠 Meminta LLM untuk menganalisis data...")
    response = llm.invoke(prompt_template)
    final_result = response.content

    print(f"✅ Jawaban dari LLM: {final_result}")

    # Langkah 4: Proses output dari LLM
    return [line.strip() for line in final_result.splitlines() if line.strip()]

# %%
# 4. Membaca file menu.csv
# -----------------------------------------------------------------------------
df_m = pd.read_csv('menu.csv')
df_m = df_m.iloc[:, [0, 1, 3, 4]]
df_m.columns.values[1] = "menu"
df_m
# Out:
#                               id                   menu  \
# 0      clwy72wl90003tb6ldyfn6flh             Biji Kopi
# 1      clwy72wmi0005tb6loalt6v9c      Bubuk Kopi Kofind
# 2      clwy72wnl0007tb6l2ebr1f8r       Kopi Susu Kofind
# 3      clwy72wta000dtb6lakswvmbi                 Es cao
# 4      clwy72wtx000ftb6l6ikider9  Kroket Kentang Goreng
# ...                          ...                    ...
# 11662  cm3cmfcbl0041ect7xk408yyb             JUS MANGGA
# 11663  cm3cmfcdf0043ect7fzhfn84c                  MACCA
# 11664  cm3cmfcfa0045ect7e5wthhac               MILK TEA
# 11665  cm3cmfch70047ect7bqhbbk6d                   TARO
# 11666  cm3cmfczp0049ect7qcyawz35            Sempol Ayam
#
#                     restaurantId         halalCertificateId
# 0      clwy72weo0000tb6l95t6xe6m  clwy72wep0001tb6l1jws0ic7
# 1      clwy72weo0000tb6l95t6xe6m  clwy72wep0001tb6l1jws0ic7
# 2      clwy72weo0000tb6l95t6xe6m  clwy72wep0001tb6l1jws0ic7
# 3      clwy72wo80008tb6lkg91djpf  clwy72wo80009tb6l7vpgfii3
# 4      clwy72wo80008tb6lkg91djpf  clwy72wo8000atb6lp1ww7g7o
# ...                          ...                        ...
# 11662  cm3cmexqt001rect7ec01uco5  cm3cmexvz001vect7cvqqrpf4
# 11663  cm3cmexqt001rect7ec01uco5  cm3cmexvz001vect7cvqqrpf4
# 11664  cm3cmexqt001rect7ec01uco5  cm3cmexvz001vect7cvqqrpf4
# 11665  cm3cmexqt001rect7ec01uco5  cm3cmexvz001vect7cvqqrpf4
# 11666  cm3cmexxx001wect7w0i1f01y  cm3cmey3h0021ect759lgxmit
#
# [11667 rows x 4 columns]

# %%
# 5. Membaca file restaurant.csv
# -----------------------------------------------------------------------------
df_r = pd.read_csv('restaurant.csv')
df_r = df_r.iloc[:, [0, 1, 2, 24]]
df_r.columns.values[0] = "restaurantId"
df_r.columns.values[1] = "restaurant"
df_r
# Out:
#                    restaurantId         restaurant  \
# 0     clwy72y970027tb6l8zm62xlf      Tue-Kue Jajan
# 1     clwy72yxr0035tb6lo0y0ujsn     Ratna Catering
# 2     clwy7316p0065tb6lxd8qado4        Cemal-Cemil
# 3     clwy733ro009ltb6lst1pp7u9       Dapoer Mekar
# 4     clwy73dps00n4tb6lvn88szcw  Dapur Mak Brintik
# ...                         ...                ...
# 2945  cm2v1gkoi0050e2ow2mvq53ys          Purbarasa
# 2946  cm2v1gl6e0055e2owxv5hd7qp         BIOTA LAUT
# 2947  cm33qx6qf003dmcyrubwqbhly     Boemboe Mandeh
# 2948  cm33qx8v90051mcyrwerr1ym1       Pusako Bundo
# 2949  cm33qx9qo005qmcyryxj7bupz             Nien's
#
#                                                 address                   city
# 0     Pasar Sawojajar Bedak C-3, Jl. Danau Bratan Ti...                 Malang
# 1     Jl. Bendul Merisi Selatan I No.109, Bendul Mer...               Surabaya
# 2     Jl. Juwingan No.136, Kertajaya, Kec. Gubeng, S...               Surabaya
# 3     Jl. Simpang Sulfat Utara No.9, Pandanwangi, Ke...                 Malang
# 4     Jl. MT. Haryono No.193, Dinoyo, Kec. Lowokwaru...                 Malang
# ...                                                 ...                    ...
# 2945  Nglanggeran Wetan, RT 16 RW 04, Kel. Nglangger...       Kab. Gunungkidul
# 2946  Jl. Berangas KM. 19 RT 001 RW 001, Desa Teluk ...         Kab. Kota Baru
# 2947  Jalan Datuak Bandaro Kuniang, Perumahan Kharis...  Kabupaten Tanah Datar
# 2948       Jl Ade Irma Suryani no 20 A Payakumbuh Utara        Kota Payakumbuh
# 2949                 Jl. Garuda Blok D 148 BTN Kotaraja          Kota Jayapura
#
# [2950 rows x 4 columns]

# %%
# 6. Menghitung nilai tidak null pada kolom 'city'
# -----------------------------------------------------------------------------
df_r['city'].notnull().sum()
# Out:
# 2756

# %%
# 7. Split kolom 'address' pada tabel df_r
# -----------------------------------------------------------------------------
df_r['address'] = df_r['address'].str.split(", ")
df_r
# Out:
#                    restaurantId         restaurant  \
# 0     clwy72y970027tb6l8zm62xlf      Tue-Kue Jajan
# 1     clwy72yxr0035tb6lo0y0ujsn     Ratna Catering
# 2     clwy7316p0065tb6lxd8qado4        Cemal-Cemil
# 3     clwy733ro009ltb6lst1pp7u9       Dapoer Mekar
# 4     clwy73dps00n4tb6lvn88szcw  Dapur Mak Brintik
# ...                         ...                ...
# 2945  cm2v1gkoi0050e2ow2mvq53ys          Purbarasa
# 2946  cm2v1gl6e0055e2owxv5hd7qp         BIOTA LAUT
# 2947  cm33qx6qf003dmcyrubwqbhly     Boemboe Mandeh
# 2948  cm33qx8v90051mcyrwerr1ym1       Pusako Bundo
# 2949  cm33qx9qo005qmcyryxj7bupz             Nien's
#
#                                                 address                   city
# 0     [Pasar Sawojajar Bedak C-3, Jl. Danau Bratan T...                 Malang
# 1     [Jl. Bendul Merisi Selatan I No.109, Bendul Me...               Surabaya
# 2     [Jl. Juwingan No.136, Kertajaya, Kec. Gubeng, ...               Surabaya
# 3     [Jl. Simpang Sulfat Utara No.9, Pandanwangi, K...                 Malang
# 4     [Jl. MT. Haryono No.193, Dinoyo, Kec. Lowokwar...                 Malang
# ...                                                 ...                    ...
# 2945  [Nglanggeran Wetan, RT 16 RW 04, Kel. Nglangge...       Kab. Gunungkidul
# 2946  [Jl. Berangas KM. 19 RT 001 RW 001, Desa Teluk...         Kab. Kota Baru
# 2947  [Jalan Datuak Bandaro Kuniang, Perumahan Khari...  Kabupaten Tanah Datar
# 2948     [Jl Ade Irma Suryani no 20 A Payakumbuh Utara]        Kota Payakumbuh
# 2949               [Jl. Garuda Blok D 148 BTN Kotaraja]          Kota Jayapura
#
# [2950 rows x 4 columns]

# %%
# 8. Mengisi nilai null pada kolom 'city'
# -----------------------------------------------------------------------------
mask = df_r['city'].isna()
df_r.loc[mask, 'city'] = (
    df_r.loc[mask, 'address']
        .apply(lambda addr: addr[-3] if len(addr) > 2 else addr[0])
)
df_r
# Out:
#                    restaurantId         restaurant  \
# 0     clwy72y970027tb6l8zm62xlf      Tue-Kue Jajan
# 1     clwy72yxr0035tb6lo0y0ujsn     Ratna Catering
# 2     clwy7316p0065tb6lxd8qado4        Cemal-Cemil
# 3     clwy733ro009ltb6lst1pp7u9       Dapoer Mekar
# 4     clwy73dps00n4tb6lvn88szcw  Dapur Mak Brintik
# ...                         ...                ...
# 2945  cm2v1gkoi0050e2ow2mvq53ys          Purbarasa
# 2946  cm2v1gl6e0055e2owxv5hd7qp         BIOTA LAUT
# 2947  cm33qx6qf003dmcyrubwqbhly     Boemboe Mandeh
# 2948  cm33qx8v90051mcyrwerr1ym1       Pusako Bundo
# 2949  cm33qx9qo005qmcyryxj7bupz             Nien's
#
#                                                 address                   city
# 0     [Pasar Sawojajar Bedak C-3, Jl. Danau Bratan T...                 Malang
# 1     [Jl. Bendul Merisi Selatan I No.109, Bendul Me...               Surabaya
# 2     [Jl. Juwingan No.136, Kertajaya, Kec. Gubeng, ...               Surabaya
# 3     [Jl. Simpang Sulfat Utara No.9, Pandanwangi, K...                 Malang
# 4     [Jl. MT. Haryono No.193, Dinoyo, Kec. Lowokwar...                 Malang
# ...                                                 ...                    ...
# 2945  [Nglanggeran Wetan, RT 16 RW 04, Kel. Nglangge...       Kab. Gunungkidul
# 2946  [Jl. Berangas KM. 19 RT 001 RW 001, Desa Teluk...         Kab. Kota Baru
# 2947  [Jalan Datuak Bandaro Kuniang, Perumahan Khari...  Kabupaten Tanah Datar
# 2948     [Jl Ade Irma Suryani no 20 A Payakumbuh Utara]        Kota Payakumbuh
# 2949               [Jl. Garuda Blok D 148 BTN Kotaraja]          Kota Jayapura
#
# [2950 rows x 4 columns]

# %%
# 9. Menghitung nilai tidak null pada kolom 'city'
# -----------------------------------------------------------------------------
df_r['city'].notnull().sum()
# Out:
# 2950

# %%
# 10. Join tabel df_m dan df_r
# -----------------------------------------------------------------------------
wave = pd.merge(df_m, df_r, on='restaurantId')
wave = wave.drop(['id', 'restaurantId', 'halalCertificateId'], axis=1)
wave
# Out:
#                         menu      restaurant  \
# 0                 Biji Kopi           KOFIND
# 1          Bubuk Kopi Kofind          KOFIND
# 2           Kopi Susu Kofind          KOFIND
# 3                     Es cao        Dapur F2
# 4      Kroket Kentang Goreng        Dapur F2
# ...                      ...             ...
# 11662             JUS MANGGA       Putri Jus
# 11663                  MACCA       Putri Jus
# 11664               MILK TEA       Putri Jus
# 11665                   TARO       Putri Jus
# 11666            Sempol Ayam  Sempol Endoeng
#
#                                                  address           city
# 0      [Jl. Kebonsari Tengah No.103, Kebonsari, Kec. ...       Surabaya
# 1      [Jl. Kebonsari Tengah No.103, Kebonsari, Kec. ...       Surabaya
# 2      [Jl. Kebonsari Tengah No.103, Kebonsari, Kec. ...       Surabaya
# 3      [Jl. Kejawan Gebang No.7, Gebang Putih, Kec. S...       Surabaya
# 4      [Jl. Kejawan Gebang No.7, Gebang Putih, Kec. S...       Surabaya
# ...                                                  ...            ...
# 11662       [KARAH V-D/87-B3, RT/RW -, KARAH, JAMBANGAN]  KOTA SURABAYA
# 11663       [KARAH V-D/87-B3, RT/RW -, KARAH, JAMBANGAN]  KOTA SURABAYA
# 11664       [KARAH V-D/87-B3, RT/RW -, KARAH, JAMBANGAN]  KOTA SURABAYA
# 11665       [KARAH V-D/87-B3, RT/RW -, KARAH, JAMBANGAN]  KOTA SURABAYA
# 11666  [KEDINDING LOR NO. 36, RT/RW -, TANAH KALI KED...  KOTA SURABAYA
#
# [11667 rows x 4 columns]

# %%
# 11. Mengelompokkan menu berdasarkan restoran
# -----------------------------------------------------------------------------
wave_group = wave.groupby(["restaurant"])["menu"].apply(list).reset_index()
wave_group
# Out:
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2827                                   virinda food
# 2828                                       wouwcake
# 2829                                        yuk tri
# 2830                                           zara
# 2831  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...
# 3                            [KRUPUK BAWANG RANIS KDS ]
# 4                         [Kacang Goreng Winarti Snack]
# ...                                                 ...
# 2827                                   [Rolade, Sempol]
# 2828  [risoles wouwcake, kue tar wouwcake, kroket ke...
# 2829       [kue nastar, kue kastengel, kue putri salju]
# 2830                                   [stik keju zara]
# 2831                 [Tape Ketan Kartika Khas Kuningan]
#
# [2832 rows x 2 columns]

# %%
# 12. Join tabel wave_group dan df_r
# -----------------------------------------------------------------------------
wave_group = pd.merge(wave_group, df_r, on='restaurant', how='left')
wave_group = wave_group.drop(['restaurantId', 'address'], axis=1)
wave_group
# Out:
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2914                                   virinda food
# 2915                                       wouwcake
# 2916                                        yuk tri
# 2917                                           zara
# 2918  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu              city
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...          Surabaya
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...  Kabupaten Gresik
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...            Malang
# 3                            [KRUPUK BAWANG RANIS KDS ]            Malang
# 4                         [Kacang Goreng Winarti Snack]          Surabaya
# ...                                                 ...               ...
# 2914                                   [Rolade, Sempol]            Malang
# 2915  [risoles wouwcake, kue tar wouwcake, kroket ke...          Surabaya
# 2916       [kue nastar, kue kastengel, kue putri salju]            Malang
# 2917                                   [stik keju zara]            Malang
# 2918                 [Tape Ketan Kartika Khas Kuningan]        Kota Depok
#
# [2919 rows x 3 columns]

# %%
# 13. Drop data restoran duplikat pada tabel wave_group
# -----------------------------------------------------------------------------
# Sort the dataframe to prioritize rows with non-null city values
wave_group_sorted = wave_group.sort_values(by='city', ascending=False)

# Drop duplicate rows based on the 'restaurant' column, keeping the first occurrence
wave_group = wave_group_sorted.drop_duplicates(subset=['restaurant'], keep='first').sort_index().reset_index()

wave_group = wave_group.drop(['index'], axis=1)

wave_group
# Out:
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2827                                   virinda food
# 2828                                       wouwcake
# 2829                                        yuk tri
# 2830                                           zara
# 2831  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu              city
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...          Surabaya
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...  Kabupaten Gresik
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...            Malang
# 3                            [KRUPUK BAWANG RANIS KDS ]            Malang
# 4                         [Kacang Goreng Winarti Snack]          Surabaya
# ...                                                 ...               ...
# 2827                                   [Rolade, Sempol]            Malang
# 2828  [risoles wouwcake, kue tar wouwcake, kroket ke...          Surabaya
# 2829       [kue nastar, kue kastengel, kue putri salju]            Malang
# 2830                                   [stik keju zara]            Malang
# 2831                 [Tape Ketan Kartika Khas Kuningan]        Kota Depok
#
# [2832 rows x 3 columns]

# %%
hasil = []
for idx, row in wave_group.iterrows():
    alts = get_similar_restaurants(row["restaurant"], row["city"])
    emb = embedder.embed_documents(alts)

    hasil.append({
        "restaurant": row["restaurant"],
        "menu": row["menu"],
        "city": row["city"],
        "alt_resto": alts,
        "embedding": emb
    })

    print(f"Jumlah embedding saat ini: {len(hasil)}")

df_hasil = pd.DataFrame(hasil)
df_hasil
# Out:
# 🔍 Mencari data di Google Maps untuk: 'restoran mirip  BP Kerupuk Sayur di Surabaya'
# 📝 Data dari Maps:
# ---
# Nama: Dapur Fizzul (Surabaya) - Rumah Makan Khas Maluku No.1 di Dunia, Alamat: depan Politeknik Kesehatan Kemeskes Surabaya Samping Hotel Kita, Jl. Karang Menjangan No.15, Mojo, Kec. Gubeng, Surabaya, Jawa Timur 60285, Indonesia
# Nama: Warung Kuning, Alamat: Jl. Kalibokor Selatan, Baratajaya, Kec. Gubeng, Surabaya, Jawa Timur 60284, Indonesia
# Nama: Arunaya Resto, Alamat: Jl. Bengawan No.5-7, Darmo, Kec. Wonokromo, Surabaya, Jawa Timur 60241, Indonesia
# ---
#
# 🧠 Meminta LLM untuk menganalisis data...
# ✅ Jawaban dari LLM: Dapur Fizzul
# Jumlah embedding saat ini: 1
# 🔍 Mencari data di Google Maps untuk: 'restoran mirip  Bumbu Rawon di Kabupaten Gresik'
# 📝 Data dari Maps:
# ---
# Nama: Rawon Balungan H. Mufid, Alamat: GKB, Jl. Kalimantan No.77-79 Kav.5, Wonorejo, Yosowilangun, Kec. Manyar, Kabupaten Gresik, Jawa Timur 61151, Indonesia
# Nama: Rawon Tulang Pak Nawi, Alamat: Jl. Gubernur Suryo No.14, Pojok, Tlogopojok, Kec. Gresik, Kabupaten Gresik, Jawa Timur 61117, Indonesia
# Nama: Rawon Cak Moek, Alamat: RMR3+5QG, Jl. Pahlawan Gg. XII, Bedilan, Kebungson, Kec. Gresik, Kabupaten Gresik, Jawa Timur 61113, Indonesia
# ---
#
# 🧠 Meminta LLM untuk menganalisis data...
# ✅ Jawaban dari LLM: Rawon Balungan H. Mufid
# Jumlah embedding saat ini: 2
# 🔍 Mencari data di Google Maps untuk: 'restoran mirip  JAMU  BU SOLIKAH di Malang'
# 📝 Data dari Maps:
# ---
# Nama: Sambat Luwe, Alamat: Jl. Mayjen Sungkono No.9, Bumiayu, Kec. Kedungkandang, Kota Malang, Jawa Timur 65135, Indonesia
# 🔍 Mencari data di Google Maps untuk: 'restoran mirip zara di Malang'
# 📝 Data dari Maps:
# ---
# Nama: Elpico Food Park, Alamat: 2HPV+G7X, Sumberjo, Kalisongo, Kec. Dau, Kabupaten Malang, Jawa Timur 65151, Indonesia
# Nama: Malang Town Square, Alamat: Jl. Veteran No.2, Penanggungan, Kec. Klojen, Kota Malang, Jawa Timur 65111, Indonesia
# Nama: Lafayette Coffee & Eatery, Alamat: Jl. Semeru No.2, RW.4, Oro-oro Dowo, Kec. Klojen, Kota Malang, Jawa Timur 65119, Indonesia
# ---
#
# 🧠 Meminta LLM untuk menganalisis data...
# ✅ Jawaban dari LLM: Lafayette Coffee & Eatery
# Jumlah embedding saat ini: 2831
# 🔍 Mencari data di Google Maps untuk: 'restoran mirip “Kartika” Tape Ketan Khas Kuningan Jawa Barat di Kota Depok'
# 📝 Data dari Maps:
# ---
# Nama: Tape Ketan Putih Khas Kuningan, Alamat: Jl. Citayam 2 No.68, Depok, Kec. Pancoran Mas, Kota Depok, Jawa Barat 16431, Indonesia
# ---
#
# 🧠 Meminta LLM untuk menganalisis data...
# ✅ Jawaban dari LLM: Tape Ketan Putih Khas Kuningan
# Jumlah embedding saat ini: 2832
#                                          restaurant  \
# 0                                  BP Kerupuk Sayur
# 1                                       Bumbu Rawon
# 2                                  JAMU  BU SOLIKAH
# 3                                        RANIS KDS
# 4                                     Winarti Snack
# ...                                             ...
# 2827                                   virinda food
# 2828                                       wouwcake
# 2829                                        yuk tri
# 2830                                           zara
# 2831  “Kartika” Tape Ketan Khas Kuningan Jawa Barat
#
#                                                    menu              city  \
# 0     [Kerupuk Labu BP Kerupuk Sayur, Kerupuk Wortel...          Surabaya
# 1     [Bumbu Rawon UKG (Usaha Kerta Gemilang), Bumbu...  Kabupaten Gresik
# 2     [JAMU KUNIR SURUH, JAMU KUNIR, JAMU BERAS KENC...            Malang
# 3                            [KRUPUK BAWANG RANIS KDS ]            Malang
# 4                         [Kacang Goreng Winarti Snack]          Surabaya
# ...                                                 ...               ...
# 2827                                   [Rolade, Sempol]            Malang
# 2828  [risoles wouwcake, kue tar wouwcake, kroket ke...          Surabaya
# 2829       [kue nastar, kue kastengel, kue putri salju]            Malang
# 2830                                   [stik keju zara]            Malang
# 2831                 [Tape Ketan Kartika Khas Kuningan]        Kota Depok
#
#                              alt_resto  \
# 0                       [Dapur Fizzul]
# 1            [Rawon Balungan H. Mufid]
# 2                        [Sambat Luwe]
# 3           [KDS Cantonese Restaurant]
# 4               [Nathania Snack House]
# ...                                ...
# 2827                  [Javanine Resto]
# 2828           [Warung wong lue (WWL)]
# 2829                  [Trimurti Resto]
# 2830       [Lafayette Coffee & Eatery]
# 2831  [Tape Ketan Putih Khas Kuningan]
#
#                                               embedding
# 0     [[-0.019313940289107857, 0.026720912450162143,...
# 1     [[-0.0012182795813163079, 0.038871749931996775...
# 2     [[0.01761782175153306, -0.006151651518221604, ...
# 3     [[-0.004616941175124867, -0.033262963255641514...
# 4     [[-0.023377033971692975, -0.013525635448501444...
# ...                                                 ...
# 2827  [[-0.04503288453259202, -0.04508640205255267, ...
# 2828  [[-0.04631182359458489, -0.01782587469255922, ...
# 2829  [[0.006737446523112387, 0.007663352942509597, ...
# 2830  [[-0.05076225249692837, -0.05180014440515231, ...
# 2831  [[-0.0075759993743668855, 0.01378592829603033,...
#
# [2832 rows x 5 columns]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
df_hasil.to_csv("wave_emb_small.csv")
